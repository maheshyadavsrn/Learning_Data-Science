# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop('PassengerId',axis=1)  # hames ke liye nahi delete hota
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop('PassengerId',axis=1,inplace=True) #hamesa ke liye delete

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.drop('PassengerId',axis=1, inpalce=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.drop('PassengerId',axis=1, inpalce=True)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# TypeError: DataFrame.drop() got an unexpected keyword argument 'inpalce'

# %%
df.drop(3,inplace=True)

# %%
df.set_index("Name",inplace=True)

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df.reset_index()
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
d = {'key1':[9,8,7,7],
     'key2':[9,9,9,9],
     'key3':[9,8,6,7]
}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     9     9     9
# 1     8     9     8
# 2     7     9     6
# 3     7     9     7

# %%
pd.read_csv("https://docs.google.com/spreadsheets/d/1XJWhtAT0YH_g8aavhkfKI7w96g_9cENG/edit?usp=drive_link&ouid=115012082006614017312&rtpof=true&sd=true")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 pd.read_csv("https://docs.google.com/spreadsheets/d/1XJWhtAT0YH_g8aavhkfKI7w96g_9cENG/edit?usp=drive_link&ouid=115012082006614017312&rtpof=true&sd=true")
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
# ...

# %%
df1=pd.read_csv('data1.csv')

# %%
df1

# %%
df1.dropna() #jnha jnha null value raheda use delete kr dega

# %%
df2= pd.read_csv('data1.csv')

# %%
df2
# Out:
#                         hlpi_name  year   hlpi  tot_hhs      own  own_wm  \
# 0                  All households  2008  allhh  1560859  1087580  574406
# 1                     Beneficiary  2008  benef   185965    71256   39405
# 2         Income quintile 1 (low)  2008  disq1   312376   191470   48424
# 3               Income quintile 2  2008  disq2   312333   196203   84171
# 4               Income quintile 3  2008  disq3   312240   217657  141318
# ..                            ...   ...    ...      ...      ...     ...
# 65         Expenditure quintile 3  2020  expq3   352564   213893  119637
# 66         Expenditure quintile 4  2020  expq4   350182   235256  141104
# 67  Expenditure quintile 5 (high)  2020  expq5   351328   288779  187838
# 68                          Māori  2020  maori   329588   156459  107753
# 69                 Superannuitant  2020  super   388013   314154   38270
#
#     own_prop  own_wm_prop  prop_hhs   age  size  income  expenditure  \
# ...

# %%
df2.fillna("mahesh")  #jnha null hoga wnha mahesh fill ho jayega
# Out:
#                         hlpi_name  year   hlpi  tot_hhs      own  own_wm  \
# 0                  All households  2008  allhh  1560859  1087580  574406
# 1                     Beneficiary  2008  benef   185965    71256   39405
# 2         Income quintile 1 (low)  2008  disq1   312376   191470   48424
# 3               Income quintile 2  2008  disq2   312333   196203   84171
# 4               Income quintile 3  2008  disq3   312240   217657  141318
# ..                            ...   ...    ...      ...      ...     ...
# 65         Expenditure quintile 3  2020  expq3   352564   213893  119637
# 66         Expenditure quintile 4  2020  expq4   350182   235256  141104
# 67  Expenditure quintile 5 (high)  2020  expq5   351328   288779  187838
# 68                          Māori  2020  maori   329588   156459  107753
# 69                 Superannuitant  2020  super   388013   314154   38270
#
#     own_prop  own_wm_prop  prop_hhs   age  size  income  expenditure  \
# ...

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
g=df.groupby('Survived')

# %%
g

# %%
g.sum()
# Out:
# /tmp/ipykernel_97/1197020669.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#           Pclass       Age  SibSp  Parch        Fare
# Survived
# 0           1390  12985.50    304    181  12142.7199
# 1            666   8184.67    161    159  16498.1294

# %%
g.mean()
# Out:
# /tmp/ipykernel_97/2978112660.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.mean()
#             Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887
# 1         1.953079  28.320657  0.472141  0.466276  48.381611

# %%
g1=df.groupby('Pclass')

# %%
g1.sum()
# Out:
# /tmp/ipykernel_97/2725926089.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.sum()
#         Survived      Age  SibSp  Parch        Fare
# Pclass
# 1            135  7076.42     89     77  18124.3125
# 2             87  5168.83     74     70   3801.8417
# 3            119  8924.92    302    193   6714.6951

# %%
g1.mean()
# Out:
# /tmp/ipykernel_97/3287460031.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.mean()
#         Survived        Age     SibSp     Parch       Fare
# Pclass
# 1       0.627907  38.250919  0.413953  0.358140  84.299128
# 2       0.472826  29.877630  0.402174  0.380435  20.662183
# 3       0.242363  25.140620  0.615071  0.393075  13.675550

# %%
g1.max()
# Out:
# /tmp/ipykernel_97/130714741.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max()
#         Survived   Sex   Age  SibSp  Parch      Ticket      Fare
# Pclass
# 1              1  male  80.0      3      4   WE/P 5735  512.3292
# 2              1  male  70.0      3      3   W/C 14208   73.5000
# 3              1  male  74.0      8      6  W./C. 6609   69.5500

# %%
g1.max()['Fare']
# Out:
# /tmp/ipykernel_97/730728694.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max()['Fare']
# Pclass
# 1    512.3292
# 2     73.5000
# 3     69.5500
# Name: Fare, dtype: float64

# %%
g1.max().T
# Out:
# /tmp/ipykernel_97/2755232466.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max().T
# Pclass            1          2           3
# Survived          1          1           1
# Sex            male       male        male
# Age            80.0       70.0        74.0
# SibSp             3          3           8
# Parch             4          3           6
# Ticket    WE/P 5735  W/C 14208  W./C. 6609
# Fare       512.3292       73.5       69.55

# %%
g1.max().transpose()
# Out:
# /tmp/ipykernel_97/3907411846.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max().transpose()
# Pclass            1          2           3
# Survived          1          1           1
# Sex            male       male        male
# Age            80.0       70.0        74.0
# SibSp             3          3           8
# Parch             4          3           6
# Ticket    WE/P 5735  W/C 14208  W./C. 6609
# Fare       512.3292       73.5       69.55

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df5=df[['Survived','Pclass']][0:5]

# %%
df6=df[['Survived','Pclass']][5:10]

# %%
df5
# Out:
#                                                     Survived  Pclass
# Name
# Braund, Mr. Owen Harris                                    0       3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1
# Heikkinen, Miss. Laina                                     1       3
# Allen, Mr. William Henry                                   0       3
# Moran, Mr. James                                           0       3

# %%
df6
# Out:
#                                                    Survived  Pclass
# Name
# McCarthy, Mr. Timothy J                                   0       1
# Palsson, Master. Gosta Leonard                            0       3
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# Nasser, Mrs. Nicholas (Adele Achem)                       1       2
# Sandstrom, Miss. Marguerite Rut                           1       3

# %%
pd.concat([df5,df6]) #add kr raha hai df5+df6
# Out:
#                                                     Survived  Pclass
# Name
# Braund, Mr. Owen Harris                                    0       3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1
# Heikkinen, Miss. Laina                                     1       3
# Allen, Mr. William Henry                                   0       3
# Moran, Mr. James                                           0       3
# McCarthy, Mr. Timothy J                                    0       1
# Palsson, Master. Gosta Leonard                             0       3
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)          1       3
# Nasser, Mrs. Nicholas (Adele Achem)                        1       2
# Sandstrom, Miss. Marguerite Rut                            1       3

# %%
df7=pd.concat([df5,df6],axis=1)

# %%
df7.fillna('mahesh')
# Out:
#                                                    Survived  Pclass Survived  \
# Name
# Braund, Mr. Owen Harris                                 0.0     3.0   mahesh
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      1.0     1.0   mahesh
# Heikkinen, Miss. Laina                                  1.0     3.0   mahesh
# Allen, Mr. William Henry                                0.0     3.0   mahesh
# Moran, Mr. James                                        0.0     3.0   mahesh
# McCarthy, Mr. Timothy J                              mahesh  mahesh      0.0
# Palsson, Master. Gosta Leonard                       mahesh  mahesh      0.0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    mahesh  mahesh      1.0
# Nasser, Mrs. Nicholas (Adele Achem)                  mahesh  mahesh      1.0
# Sandstrom, Miss. Marguerite Rut                      mahesh  mahesh      1.0
#
#                                                     Pclass
# Name
# ...

# %%
data1=pd.DataFrame({'key1':[1,3,4,5,6],
                    'key2':[3,5,6,8,9],
                    'key3':[4,7,9,3,5]
                    
})

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     3     4
# 1     3     5     7
# 2     4     6     9
# 3     5     8     3
# 4     6     9     5

# %%
data2=pd.DataFrame({'key1':[1,3,48,85,6],
                    'key4':[3,5,86,8,9],
                    'key5':[4,77,9,3,5]
                    
})

# %%
data2
# Out:
#    key1  key4  key5
# 0     1     3     4
# 1     3     5    77
# 2    48    86     9
# 3    85     8     3
# 4     6     9     5

# %%
data3=pd.concat([data1,data2])

# %%
data3
# Out:
#    key1  key2  key3  key4  key5
# 0     1   3.0   4.0   NaN   NaN
# 1     3   5.0   7.0   NaN   NaN
# 2     4   6.0   9.0   NaN   NaN
# 3     5   8.0   3.0   NaN   NaN
# 4     6   9.0   5.0   NaN   NaN
# 0     1   NaN   NaN   3.0   4.0
# 1     3   NaN   NaN   5.0  77.0
# 2    48   NaN   NaN  86.0   9.0
# 3    85   NaN   NaN   8.0   3.0
# 4     6   NaN   NaN   9.0   5.0

# %%
pd.merge(data1,data2)  #intersection ho raha hai data1 me aur data2 me
# Out:
#    key1  key2  key3  key4  key5
# 0     1     3     4     3     4
# 1     3     5     7     5    77
# 2     6     9     5     9     5

# %%
pd.merge(data1,data2,how='left')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     3     4   3.0   4.0
# 1     3     5     7   5.0  77.0
# 2     4     6     9   NaN   NaN
# 3     5     8     3   NaN   NaN
# 4     6     9     5   9.0   5.0

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     3     4
# 1     3     5     7
# 2     4     6     9
# 3     5     8     3
# 4     6     9     5

# %%
data2
# Out:
#    key1  key4  key5
# 0     1     3     4
# 1     3     5    77
# 2    48    86     9
# 3    85     8     3
# 4     6     9     5

# %%
pd.merge(data1,data2,how='right')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   3.0   4.0     3     4
# 1     3   5.0   7.0     5    77
# 2    48   NaN   NaN    86     9
# 3    85   NaN   NaN     8     3
# 4     6   9.0   5.0     9     5

# %%
pd.merge(data1,data2,how='outer')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   3.0   4.0   3.0   4.0
# 1     3   5.0   7.0   5.0  77.0
# 2     4   6.0   9.0   NaN   NaN
# 3     5   8.0   3.0   NaN   NaN
# 4     6   9.0   5.0   9.0   5.0
# 5    48   NaN   NaN  86.0   9.0
# 6    85   NaN   NaN   8.0   3.0

# %%
pd.merge(data1,data2,how='cross')  #sab ka combination bana raha hai
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     3     4       1     3     4
# 1        1     3     4       3     5    77
# 2        1     3     4      48    86     9
# 3        1     3     4      85     8     3
# 4        1     3     4       6     9     5
# 5        3     5     7       1     3     4
# 6        3     5     7       3     5    77
# 7        3     5     7      48    86     9
# 8        3     5     7      85     8     3
# 9        3     5     7       6     9     5
# 10       4     6     9       1     3     4
# 11       4     6     9       3     5    77
# 12       4     6     9      48    86     9
# 13       4     6     9      85     8     3
# 14       4     6     9       6     9     5
# 15       5     8     3       1     3     4
# 16       5     8     3       3     5    77
# 17       5     8     3      48    86     9
# 18       5     8     3      85     8     3
# 19       5     8     3       6     9     5
# 20       6     9     5       1     3     4
# ...

# %%
data1=pd.DataFrame({'key1':[1,3,4,5,6],
                    'key2':[3,5,6,8,9],
                    'key3':[4,7,9,3,5]},
                    index=['a','b','c','d','e']
                    
)

# %%
data2=pd.DataFrame({'key11':[1,3,4,5,6],
                    'key22':[3,5,6,8,9],
                    'key33':[4,7,9,3,5]},
                    index=['a','b','h','i','j']
                    
)

# %%
data1
# Out:
#    key1  key2  key3
# a     1     3     4
# b     3     5     7
# c     4     6     9
# d     5     8     3
# e     6     9     5

# %%
data1.join(data2)
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     3     4    1.0    3.0    4.0
# b     3     5     7    3.0    5.0    7.0
# c     4     6     9    NaN    NaN    NaN
# d     5     8     3    NaN    NaN    NaN
# e     6     9     5    NaN    NaN    NaN

# %%
data1.join(data2,how='right')
# Out:
#    key1  key2  key3  key11  key22  key33
# a   1.0   3.0   4.0      1      3      4
# b   3.0   5.0   7.0      3      5      7
# h   NaN   NaN   NaN      4      6      9
# i   NaN   NaN   NaN      5      8      3
# j   NaN   NaN   NaN      6      9      5

# %%
data1.join(data2,how='inner')
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     3     4      1      3      4
# b     3     5     7      3      5      7

# %%
data1.join(data2,how='outer')
# Out:
#    key1  key2  key3  key11  key22  key33
# a   1.0   3.0   4.0    1.0    3.0    4.0
# b   3.0   5.0   7.0    3.0    5.0    7.0
# c   4.0   6.0   9.0    NaN    NaN    NaN
# d   5.0   8.0   3.0    NaN    NaN    NaN
# e   6.0   9.0   5.0    NaN    NaN    NaN
# h   NaN   NaN   NaN    4.0    6.0    9.0
# i   NaN   NaN   NaN    5.0    8.0    3.0
# j   NaN   NaN   NaN    6.0    9.0    5.0

# %%
data1.join(data2,how='cross')
# Out:
#     key1  key2  key3  key11  key22  key33
# 0      1     3     4      1      3      4
# 1      1     3     4      3      5      7
# 2      1     3     4      4      6      9
# 3      1     3     4      5      8      3
# 4      1     3     4      6      9      5
# 5      3     5     7      1      3      4
# 6      3     5     7      3      5      7
# 7      3     5     7      4      6      9
# 8      3     5     7      5      8      3
# 9      3     5     7      6      9      5
# 10     4     6     9      1      3      4
# 11     4     6     9      3      5      7
# 12     4     6     9      4      6      9
# 13     4     6     9      5      8      3
# 14     4     6     9      6      9      5
# 15     5     8     3      1      3      4
# 16     5     8     3      3      5      7
# 17     5     8     3      4      6      9
# 18     5     8     3      5      8      3
# 19     5     8     3      6      9      5
# 20     6     9     5      1      3      4
# ...

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df['Fare_INR']=df['Fare'].apply(lambda x:x*80)  # conver doller to rupes

# %%
df.head()
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
#
#                                                      Age  SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                             22.0      1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1      0
# Heikkinen, Miss. Laina                              26.0      0      0
# Allen, Mr. William Henry                            35.0      0      0
# Moran, Mr. James                                     NaN      0      0
#
# ...

# %%
def euro_inr(x):
    return x*80
df['Fare_INR']=df['Fare'].apply(euro_inr)

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df.head()
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
#
#                                                      Age  SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                             22.0      1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1      0
# Heikkinen, Miss. Laina                              26.0      0      0
# Allen, Mr. William Henry                            35.0      0      0
# Moran, Mr. James                                     NaN      0      0
#
# ...

# %%
df['ticket_ln']=df['Ticket'].apply(len)  #isame jo dale ahi usaka length count kar ke new colunms add ke dega

# %%
df.head()
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
#
#                                                      Age  SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                             22.0      1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1      0
# Heikkinen, Miss. Laina                              26.0      0      0
# Allen, Mr. William Henry                            35.0      0      0
# Moran, Mr. James                                     NaN      0      0
#
# ...

# %%
def cat_fare(x):
    if x<10:
        return "cheap"
    elif x>=10 and x<20:
        return 'mid'
    else:
        return 'high'

# %%
df['car_fare']=df['Fare'].apply(cat_fare)

# %%
df.head()
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
#
#                                                      Age  SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                             22.0      1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1      0
# Heikkinen, Miss. Laina                              26.0      0      0
# Allen, Mr. William Henry                            35.0      0      0
# Moran, Mr. James                                     NaN      0      0
#
# ...
