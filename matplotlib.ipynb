# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x=np.linspace(0,10,200)

# %%
x
# Out:
# array([ 0.        ,  0.05025126,  0.10050251,  0.15075377,  0.20100503,
#         0.25125628,  0.30150754,  0.35175879,  0.40201005,  0.45226131,
#         0.50251256,  0.55276382,  0.60301508,  0.65326633,  0.70351759,
#         0.75376884,  0.8040201 ,  0.85427136,  0.90452261,  0.95477387,
#         1.00502513,  1.05527638,  1.10552764,  1.15577889,  1.20603015,
#         1.25628141,  1.30653266,  1.35678392,  1.40703518,  1.45728643,
#         1.50753769,  1.55778894,  1.6080402 ,  1.65829146,  1.70854271,
#         1.75879397,  1.80904523,  1.85929648,  1.90954774,  1.95979899,
#         2.01005025,  2.06030151,  2.11055276,  2.16080402,  2.21105528,
#         2.26130653,  2.31155779,  2.36180905,  2.4120603 ,  2.46231156,
#         2.51256281,  2.56281407,  2.61306533,  2.66331658,  2.71356784,
#         2.7638191 ,  2.81407035,  2.86432161,  2.91457286,  2.96482412,
#         3.01507538,  3.06532663,  3.11557789,  3.16582915,  3.2160804 ,
# ...

# %%
y=np.sin(x)

# %%
y
# Out:
# array([ 0.        ,  0.05023011,  0.10033341,  0.15018339,  0.19965422,
#         0.24862099,  0.29696008,  0.34454944,  0.39126893,  0.43700061,
#         0.481629  ,  0.52504145,  0.56712835,  0.60778345,  0.6469041 ,
#         0.68439153,  0.72015112,  0.75409257,  0.78613019,  0.8161831 ,
#         0.84417544,  0.87003651,  0.89370105,  0.91510929,  0.9342072 ,
#         0.95094655,  0.96528509,  0.97718662,  0.98662108,  0.99356467,
#         0.99799984,  0.99991541,  0.99930653,  0.99617474,  0.99052796,
#         0.98238043,  0.97175273,  0.95867168,  0.94317032,  0.92528777,
#         0.90506919,  0.88256563,  0.85783388,  0.8309364 ,  0.80194109,
#         0.77092115,  0.7379549 ,  0.70312557,  0.66652108,  0.62823386,
#         0.58836056,  0.54700186,  0.50426216,  0.46024937,  0.41507461,
#         0.36885193,  0.32169803,  0.27373195,  0.22507478,  0.17584939,
#         0.12618003,  0.07619211,  0.02601183, -0.02423412, -0.07441889,
# ...

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xlabel("this is my x data")
plt.ylabel("this is my y data")
plt.title("this is my title")
plt.show()

# %%
x=np.random.rand(50)
y=np.random.rand(50)
plt.scatter(x,y)

# %%
x
# Out:
# array([3.53213368e-01, 7.69966280e-01, 5.82741408e-01, 5.14423590e-01,
#        8.44402308e-01, 7.48815978e-01, 2.97996654e-01, 5.72748034e-01,
#        2.42804385e-01, 9.60411399e-01, 5.77763053e-01, 4.27198166e-01,
#        8.85550306e-01, 3.52480642e-01, 5.91403725e-01, 3.65752955e-04,
#        2.90356240e-01, 4.92941809e-01, 4.47197481e-01, 1.51598623e-01,
#        2.19325315e-01, 8.36689631e-01, 2.88741146e-02, 5.28892914e-01,
#        1.05196076e-01, 2.68899607e-01, 4.73482229e-01, 8.73758434e-01,
#        3.69755326e-01, 7.63582272e-01, 4.05423646e-01, 8.58596946e-01,
#        4.07850720e-01, 7.40713534e-01, 7.29425854e-01, 6.02816700e-01,
#        7.65265525e-01, 3.15916837e-01, 3.25661425e-01, 9.47309910e-01,
#        3.07159179e-01, 8.66510062e-01, 1.46962411e-01, 2.53819165e-01,
#        9.74592490e-01, 9.02274244e-01, 1.79409828e-02, 9.47878546e-02,
#        4.79343908e-01, 8.89659373e-01])

# %%
y
# Out:
# array([0.64438703, 0.21098014, 0.91427984, 0.0447614 , 0.37392002,
#        0.61048435, 0.83592993, 0.89082777, 0.24612479, 0.07368492,
#        0.90017251, 0.99334371, 0.58090906, 0.24504602, 0.96707054,
#        0.35496416, 0.88835958, 0.33329829, 0.33738587, 0.90346404,
#        0.37805028, 0.30096216, 0.04218684, 0.32391531, 0.94319525,
#        0.51240723, 0.69826364, 0.41659468, 0.0538995 , 0.7805165 ,
#        0.82872384, 0.18648394, 0.21369838, 0.24370726, 0.49169319,
#        0.05874032, 0.31547754, 0.31617931, 0.65536017, 0.03303855,
#        0.30463612, 0.78464115, 0.47223158, 0.39030541, 0.37458226,
#        0.80611978, 0.1217782 , 0.49585136, 0.97234654, 0.82551715])

# %%
colour =np.random.rand(50)
sizes=100*np.random.rand(50)
plt.scatter(x,y,c=colour,s=sizes,alpha=.5)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("random data")
# Out:
# Text(0.5, 1.0, 'random data')

# %%
x=['a','b','c','d','e']

# %%
y=np.random.rand(5)
plt.bar(x,y)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("bar data")
# Out:
# Text(0.5, 1.0, 'bar data')

# %%
y=np.random.rand(5)
plt.barh(x,y)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("bar data")
# Out:
# Text(0.5, 1.0, 'bar data')

# %%
y=np.random.rand(5)

plt.plot(x,y,'--b')
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("bar data")
plt.grid()
plt.show()

# %%
x=np.random.rand(50)
y=np.random.rand(50)
plt.scatter(x,y)
colour =np.random.rand(50)
sizes=500*np.random.rand(50)
plt.scatter(x,y,c='#000',s=sizes,alpha=.5,marker="v")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("random data")
# Out:
# Text(0.5, 1.0, 'random data')

# %%
x=[4,5,6,7,8,9]
y=[6,7,8,9,10,11]
plt.plot(x,y)
plt.show()

# %%
x=[4,5,6,7,8,9]
y=[60,30,80,9,30,11]
plt.scatter(x,y)
plt.show()

# %%
x=[4,5,6,7,8,9]
y=[60,30,80,9,30,11]
plt.plot(x,y)
plt.show()

# %%
data=[1,2,3,4,5,1,2,8,9,0,1,2,3,7,7]

# %%
plt.hist(data)
plt.show()    #konsa number kitani bar aaya hai usi ke hisab se graph plot hua hai

# %%
x = [4, 5, 6, 7, 8, 9]
y = [60, 30, 80, 9, 30, 11]
colour = ['red', 'blue', '#000', '#fff', '#000', '#00ff00']

plt.scatter(x, y, c=colour)
plt.show()

# %%
x=np.random.rand(50)
y=np.random.rand(50)
z=np.random.rand(50)

fig=plt.figure()
ax=fig.add_subplot(projection='3d')
ax.scatter(x,y,z)
plt.show()
